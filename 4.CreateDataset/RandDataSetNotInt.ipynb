# %%
import numpy as np
import pandas as pd
from random import seed
from random import random

# %%
np.random.seed(1234)

dim2_1000 = np.random.rand(1000,2)
dim2_10000 = np.random.rand(10000,2)
dim2_30000 = np.random.rand(30000,2)


dim4_1000 = np.random.rand(1000,4)
dim4_10000 = np.random.rand(10000,4)
dim4_30000 = np.random.rand(30000,4)


dim8_1000 = np.random.rand(1000,8)
dim8_10000 = np.random.rand(10000,8)
dim8_30000 = np.random.rand(30000,8)

dim16_1000 = np.random.rand(1000,16)
dim16_10000 = np.random.rand(10000,16)
dim16_30000 = np.random.rand(30000,16)

dim20_1000 = np.random.rand(1000,20)
dim20_10000 = np.random.rand(10000,20)
dim20_30000 = np.random.rand(30000,20)

dim30_1000 = np.random.rand(1000,30)
dim30_10000 = np.random.rand(10000,30)
dim30_30000 = np.random.rand(30000,30)

dim40_1000 = np.random.rand(1000,40)
dim40_10000 = np.random.rand(10000,40)
dim40_30000 = np.random.rand(30000,40)

dim50_1000 = np.random.rand(1000,50)
dim50_10000 = np.random.rand(10000,50)
dim50_30000 = np.random.rand(30000,50)

df2_1000 = pd.DataFrame(dim2_1000)
df2_1000.to_csv('2DiRanData.csv',index=False)
df2_10000 = pd.DataFrame(dim2_10000)
df2_10000.to_csv('2DiRanData_10000.csv',index=False)
df2_30000 = pd.DataFrame(dim2_30000)
df2_30000.to_csv('2DiRanData_30000.csv',index=False)

df4_1000 = pd.DataFrame(dim4_1000)
df4_1000.to_csv('4DiRanData.csv',index=False)
df4_10000 = pd.DataFrame(dim4_10000)
df4_10000.to_csv('4DiRanData_10000.csv',index=False)
df4_30000 = pd.DataFrame(dim4_30000)
df4_30000.to_csv('4DiRanData_30000.csv',index=False)

df8_1000 = pd.DataFrame(dim8_1000)
df8_1000.to_csv('8DiRanData.csv',index=False)
df8_10000 = pd.DataFrame(dim8_10000)
df8_10000.to_csv('8DiRanData_10000.csv',index=False)
df8_30000 = pd.DataFrame(dim8_30000)
df8_30000.to_csv('8DiRanData_30000.csv',index=False)

df16_1000 = pd.DataFrame(dim16_1000)
df16_1000.to_csv('16DiRanData.csv',index=False)
df16_10000 = pd.DataFrame(dim16_10000)
df16_10000.to_csv('16DiRanData_10000.csv',index=False)
df16_30000 = pd.DataFrame(dim16_30000)
df16_30000.to_csv('16DiRanData_30000.csv',index=False)

df20_1000 = pd.DataFrame(dim20_1000)
df20_1000.to_csv('20DiRanData.csv',index=False)
df20_10000 = pd.DataFrame(dim20_10000)
df20_10000.to_csv('20DiRanData_10000.csv',index=False)
df20_30000 = pd.DataFrame(dim20_30000)
df20_30000.to_csv('20DiRanData_30000.csv',index=False)

df30_1000 = pd.DataFrame(dim30_1000)
df30_1000.to_csv('30DiRanData.csv',index=False)
df30_10000 = pd.DataFrame(dim30_10000)
df30_10000.to_csv('30DiRanData_10000.csv',index=False)
df30_30000 = pd.DataFrame(dim30_30000)
df30_30000.to_csv('30DiRanData_30000.csv',index=False)

df40_1000 = pd.DataFrame(dim40_1000)
df40_1000.to_csv('40DiRanData.csv',index=False)
df40_10000 = pd.DataFrame(dim40_10000)
df40_10000.to_csv('40DiRanData_10000.csv',index=False)
df40_30000 = pd.DataFrame(dim40_30000)
df40_30000.to_csv('40DiRanData_30000.csv',index=False)

df50_1000 = pd.DataFrame(dim50_1000)
df50_1000.to_csv('50DiRanData.csv',index=False)
df50_10000 = pd.DataFrame(dim50_10000)
df50_10000.to_csv('50DiRanData_10000.csv',index=False)
df50_30000 = pd.DataFrame(dim50_30000)
df50_30000.to_csv('50DiRanData_30000.csv',index=False)

# %%
dim5_1000 = np.random.rand(1000,5)
dim5_10000 = np.random.rand(10000,5)
dim5_30000 = np.random.rand(30000,5)

df5_1000 = pd.DataFrame(dim5_1000)
df5_1000.to_csv('5DiRanData.csv',index=False)
df5_10000 = pd.DataFrame(dim5_10000)
df5_10000.to_csv('5DiRanData_10000.csv',index=False)
df5_30000 = pd.DataFrame(dim5_30000)
df5_30000.to_csv('5DiRanData_30000.csv',index=False)

dim10_1000 = np.random.rand(1000,10)
dim10_10000 = np.random.rand(10000,10)
dim10_30000 = np.random.rand(30000,10)

df10_1000 = pd.DataFrame(dim10_1000)
df10_1000.to_csv('10DiRanData.csv',index=False)
df10_10000 = pd.DataFrame(dim10_10000)
df10_10000.to_csv('10DiRanData_10000.csv',index=False)
df10_30000 = pd.DataFrame(dim10_30000)
df10_30000.to_csv('10DiRanData_30000.csv',index=False)

dim15_1000 = np.random.rand(1000,15)
dim15_10000 = np.random.rand(10000,15)
dim15_30000 = np.random.rand(30000,15)

df15_1000 = pd.DataFrame(dim15_1000)
df15_1000.to_csv('15DiRanData.csv',index=False)
df15_10000 = pd.DataFrame(dim15_10000)
df15_10000.to_csv('15DiRanData_10000.csv',index=False)
df15_30000 = pd.DataFrame(dim15_30000)
df15_30000.to_csv('15DiRanData_30000.csv',index=False)

dim20_1000 = np.random.rand(1000,20)
dim20_10000 = np.random.rand(10000,20)
dim20_30000 = np.random.rand(30000,20)

df20_1000 = pd.DataFrame(dim20_1000)
df20_1000.to_csv('20DiRanData.csv',index=False)
df20_10000 = pd.DataFrame(dim20_10000)
df20_10000.to_csv('20DiRanData_10000.csv',index=False)
df20_30000 = pd.DataFrame(dim20_30000)
df20_30000.to_csv('20DiRanData_30000.csv',index=False)

dim30_1000 = np.random.rand(1000,30)
dim30_10000 = np.random.rand(10000,30)
dim30_30000 = np.random.rand(30000,30)

df30_1000 = pd.DataFrame(dim30_1000)
df30_1000.to_csv('30DiRanData.csv',index=False)
df30_10000 = pd.DataFrame(dim30_10000)
df30_10000.to_csv('30DiRanData_10000.csv',index=False)
df30_30000 = pd.DataFrame(dim30_30000)
df30_30000.to_csv('30DiRanData_30000.csv',index=False)

dim40_1000 = np.random.rand(1000,40)
dim40_10000 = np.random.rand(10000,40)
dim40_30000 = np.random.rand(30000,40)

df40_1000 = pd.DataFrame(dim40_1000)
df40_1000.to_csv('40DiRanData.csv',index=False)
df40_10000 = pd.DataFrame(dim40_10000)
df40_10000.to_csv('40DiRanData_10000.csv',index=False)
df40_30000 = pd.DataFrame(dim40_30000)
df40_30000.to_csv('40DiRanData_30000.csv',index=False)

dim50_1000 = np.random.rand(1000,50)
dim50_10000 = np.random.rand(10000,50)
dim50_30000 = np.random.rand(30000,50)

df50_1000 = pd.DataFrame(dim50_1000)
df50_1000.to_csv('50DiRanData.csv',index=False)
df50_10000 = pd.DataFrame(dim50_10000)
df50_10000.to_csv('50DiRanData_10000.csv',index=False)
df50_30000 = pd.DataFrame(dim50_30000)
df50_30000.to_csv('50DiRanData_30000.csv',index=False)

# %%
dim25_1000 = np.random.rand(1000,25)
dim25_10000 = np.random.rand(10000,25)
dim25_30000 = np.random.rand(30000,25)

df25_1000 = pd.DataFrame(dim25_1000)
df25_1000.to_csv('25DiRanData.csv',index=False)
df25_10000 = pd.DataFrame(dim25_10000)
df25_10000.to_csv('25DiRanData_10000.csv',index=False)
df25_30000 = pd.DataFrame(dim25_30000)
df25_30000.to_csv('25DiRanData_30000.csv',index=False)
